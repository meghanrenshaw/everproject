# %% [markdown]
# <a href="https://colab.research.google.com/github/meghanrenshaw/everproject/blob/master/ever_meghanrenshaw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imported pandas to be able to use data from the excel sheet
#import numpy as np
import pandas as pd 
import openpyxl, pprint
wb = openpyxl.load_workbook('english_emotionlexicon.txt.xlsx')
# sheet = wb.get_sheet_by_name('emotion')
import string
string.punctuation
from datetime import date
from datetime import time
from datetime import datetime
from collections import Counter

# %%
# titled the data from the excel sheet 'emotionsData'
emotionsData = pd.read_excel('english_emotionlexicon.txt.xlsx', index_col=0)
emotionsData
# Out:
#               Anger  Anticipation  Disgust  Fear  Joy  Sadness  Surprise  Trust
# English (en)
# aback             0             0        0     0    0        0         0      0
# abacus            0             0        0     0    0        0         0      1
# abandon           0             0        0     1    0        1         0      0
# abandoned         1             0        0     1    0        1         0      0
# abandonment       1             0        0     1    0        1         1      0
# ...             ...           ...      ...   ...  ...      ...       ...    ...
# zone              0             0        0     0    0        0         0      0
# zoo               0             0        0     0    0        0         0      0
# zoological        0             0        0     0    0        0         0      0
# zoology           0             0        0     0    0        0         0      0
# zoom              0             0        0     0    0        0         0      0
# ...

# %%
print(emotionsData)
# Out:
#               Anger  Anticipation  Disgust  Fear  Joy  Sadness  Surprise  Trust
# English (en)
# aback             0             0        0     0    0        0         0      0
# abacus            0             0        0     0    0        0         0      1
# abandon           0             0        0     1    0        1         0      0
# abandoned         1             0        0     1    0        1         0      0
# abandonment       1             0        0     1    0        1         1      0
# ...             ...           ...      ...   ...  ...      ...       ...    ...
# zone              0             0        0     0    0        0         0      0
# zoo               0             0        0     0    0        0         0      0
# zoological        0             0        0     0    0        0         0      0
# zoology           0             0        0     0    0        0         0      0
# zoom              0             0        0     0    0        0         0      0
# ...

# %%
# Named each column with their respective emotions and assigned them to 'df'
df = pd.DataFrame(emotionsData, columns = ['anger', 'anticipation', 'disgust', 'fear', 'joy', 'sadness', 'surprise', 'trust'])

# %%
print(df)
# Out:
#               anger  anticipation  disgust  fear  joy  sadness  surprise  trust
# English (en)
# aback           NaN           NaN      NaN   NaN  NaN      NaN       NaN    NaN
# abacus          NaN           NaN      NaN   NaN  NaN      NaN       NaN    NaN
# abandon         NaN           NaN      NaN   NaN  NaN      NaN       NaN    NaN
# abandoned       NaN           NaN      NaN   NaN  NaN      NaN       NaN    NaN
# abandonment     NaN           NaN      NaN   NaN  NaN      NaN       NaN    NaN
# ...             ...           ...      ...   ...  ...      ...       ...    ...
# zone            NaN           NaN      NaN   NaN  NaN      NaN       NaN    NaN
# zoo             NaN           NaN      NaN   NaN  NaN      NaN       NaN    NaN
# zoological      NaN           NaN      NaN   NaN  NaN      NaN       NaN    NaN
# zoology         NaN           NaN      NaN   NaN  NaN      NaN       NaN    NaN
# zoom            NaN           NaN      NaN   NaN  NaN      NaN       NaN    NaN
# ...

# %%
# Each column of words was assigned a name corresponding to their emotion. 
angerwords = df[df['anger']==1].index.tolist()
anticipationwords = df[df['anticipation']==1].index.tolist()
disgustwords = df[df['disgust']==1].index.tolist()
fearwords = df[df['fear']==1].index.tolist()
joywords = df[df['joy']==1].index.tolist()
sadnesswords = df[df['sadness']==1].index.tolist()
surprisewords = df[df['surprise']==1].index.tolist()
trustwords = df[df['trust']==1].index.tolist()

# %%
# ever program function 
def ever():
  """ This is a function that takes text as input and analyzes it for emotion. """

# Initializing a string to print all my output to
  printstring = ""

# Setting all emotion counters to 0.
  emocounter = [0,0,0,0,0,0,0,0]

# Setting all emotion lists to empty
  ang = []
  ant = []
  dis = [] 
  fea = [] 
  joy = []
  sad = []
  sur = [] 
  tru = []

# Concatenating all lists
  emotionwords = [angerwords, anticipationwords, disgustwords, fearwords, joywords, sadnesswords, surprisewords, trustwords]
  emotionlist = [ang, ant, dis, fea, joy, sad, sur, tru]

# Grabbing today's date
  x = date.today().strftime("%B %d, %Y")
  print(x)

# Asking user for their name and how they're doing
  name = input("My name is Ever. What's your name? ")
  name = name.title()
  print("Nice to meet you, ", name.title(), ".")
  print("")
  day = input("Tell me about your day. ")
  print("")
# Puts all words into lowercase, breaks it up into a list, and removes punctuation
  daylower = day.lower()
  daysplit = daylower.split()
  daysplit = [w.strip(string.punctuation) for w in daysplit]
  daysplit = set(daysplit)
  daysplit

# For words in user's input, if it's in one of the emotion lists, count it
  for word in daysplit: 
    for i, item in enumerate(emotionlist, 0):
      if word in emotionwords[i]:
        emocounter[i] = emocounter[i] + 1
        item.append(word)

# If each emotion's value is zero, it will ask for more information  
# If user continues to be vague, it will keep asking to be more descriptive
 # while emocounter[0] == 0 and emocounter[1] == 0 and emocounter[2] == 0 and emocounter[3] == 0 and emocounter[4] == 0 and emocounter[5] == 0 and emocounter[6] == 0 and emocounter[7] == 0:
#      print("Could you be more descriptive? ")
#      more = input()
#      print("")
#      morelower = more.lower()
#      moresplit = morelower.split()
#      moresplit = [w.strip(string.punctuation) for w in moresplit]
#      moresplit = set(moresplit)
#      for word in moresplit:
#        for i, item in enumerate(emotionlist, 0):
#          if word in emotionwords[i]:
#            emocounter[i] = emocounter[i] + 1
#            item.append(word)
#          else: pass

# Prints the emotion, the emotion's count, as well as the entire list of respective emotion
  print("Anger: ", emocounter[0], ang)
  print("Anticipation: ", emocounter[1], ant)
  print("Disgust: ", emocounter[2], dis)
  print("Fear: ", emocounter[3], fea)
  print("Joy: ", emocounter[4], joy)
  print("Sadness: ", emocounter[5], sad)
  print("Surprise: ", emocounter[6], sur)
  print("Trust: ", emocounter[7], tru)

# Compares the counts of each emotion with one another, highest count gets displayed at the end
  if emocounter[0] >= emocounter[1] and emocounter[0] >= emocounter[2] and emocounter[0] >= emocounter[3] and emocounter[0] >= emocounter[4] and emocounter[0] >= emocounter[5] and emocounter[0] >= emocounter[6] and emocounter[0] >= emocounter[7]:
    print(name, ", you are feeling angry.")
    printstring += name+", you are feeling anger. "
    yesorno = input("Would you like information on managing your anger? Type 'yes' to proceed. ")
    if yesorno.lower() == 'yes':
      print("")
      print("Here are some ways to manage your feeling of anger: ")
      print(" -Think before you speak.\n -Get some exercise.\n -Take a timeout.\n -Identify possible solutions.\n -Stick with 'I' statements.\n -Don't hold a grudge.\n -Use humor to release tension.")
    else: pass

  if emocounter[1] >= emocounter[0] and emocounter[1] >= emocounter[2] and emocounter[1] >= emocounter[3] and emocounter[1] >= emocounter[4] and emocounter[1] >= emocounter[5] and emocounter[1] >= emocounter[6] and emocounter[1] >= emocounter[7]:
    print(name, ", you are feeling anticipation.")
    printstring += name+", you are feeling anticipation. "
    yesorno = input("Would you like information on managing your anticipation? Type 'yes' to proceed. ")
    if yesorno.lower() == 'yes':
      print("")
      print("Here are some ways to interpret your feeling of anticipation: ")
      print(" -Focus on the positive and fun aspects of the upcoming event.\n -Remind yourself that the physical sensations you feel when anxious are harmless.\n -Practice mindfulness.")
    else: pass

  if emocounter[2] >= emocounter[0] and emocounter[2] >= emocounter[1] and emocounter[2] >= emocounter[3] and emocounter[2] >= emocounter[4] and emocounter[2] >= emocounter[5] and emocounter[2] >= emocounter[6] and emocounter[2] >= emocounter[7]:
    print(name, ", you are feeling disgust.")
    printstring += name+", you are feeling disgust. "
    yesorno = input("Would you like information on managing your feeling of disgust? Type 'yes' to proceed. ")
    if yesorno.lower() == 'yes':
      print("")
      print("Here are some ways to manage your feeling of disgust: ")
      print(" -Notice when judmental thoughts pop into your head.\n -Remember to breathe.\n -Don't let your feelings control your thinking.\n -Do the opposite of what you're feeling.\n -Remember, it's not about you.\n -Talk to someone you trust about your feelings.")
    else: pass

  if emocounter[3] >= emocounter[0] and emocounter[3] >= emocounter[1] and emocounter[3] >= emocounter[2] and emocounter[3] >= emocounter[4] and emocounter[3] >= emocounter[5] and emocounter[3] >= emocounter[6] and emocounter[3] >= emocounter[7]:
    print(name, ", you are feeling fear.")
    printstring += name+", you are feeling fear. "
    yesorno = input("Would you like information on managing your feeling of fear? Type 'yes' to proceed. ")
    if yesorno.lower() == 'yes':
      print("")
      print("Here are some ways to manage your feeling of fear: ")
      print(" -Face your fear if you can.\n -Exercise.\n -Relax, do yoga or meditate.\n -If you're religious, find ways to connect to something bigger than yourself.")
    else: pass

  if emocounter[4] >= emocounter[0] and emocounter[4] >= emocounter[1] and emocounter[4] >= emocounter[2] and emocounter[4] >= emocounter[3] and emocounter[4] >= emocounter[5] and emocounter[4] >= emocounter[6] and emocounter[4] >= emocounter[7]:
    print(name, ", you are feeling joy.")
    printstring += name+", you are feeling joy."
    yesorno = input("Would you like information on embracing your feeling of joy? Type 'yes' to proceed. ")
    if yesorno.lower() == 'yes':
      print("")
      print("Here are some ways to embrace your joy: ")
      print(" -Ride the productivity train.\n -Take a break and enjoy the feeling.\n -Write about it.\n -Share your joy with others by complimenting or helping someone or reaching out to friends.")
    else: pass

  if emocounter[5] >= emocounter[0] and emocounter[5] >= emocounter[1] and emocounter[5] >= emocounter[2] and emocounter[5] >= emocounter[3] and emocounter[5] >= emocounter[4] and emocounter[5] >= emocounter[6] and emocounter[5] >= emocounter[7]:
    print(name, ", you are feeling sadness.")
    printstring += name+", you are feeling sadness. "
    yesorno = input("Would you like information on regulating how sadness affects you? Type 'yes' to proceed. ")
    if yesorno.lower() == 'yes':
      print("")
      print("Here are some ways to regulate your feeling of sadness: ")
      print(" -Allow yourself to feel sad.\n -Spend time with friends or family.\n -Think about why you're feeling this way.\n -Cry if you feel like it.\n -Listen to music.\n -Write in a journal.")
    else: pass

  if emocounter[6] >= emocounter[0] and emocounter[6] >= emocounter[1] and emocounter[6] >= emocounter[2] and emocounter[6] >= emocounter[3] and emocounter[6] >= emocounter[4] and emocounter[6] >= emocounter[5] and emocounter[6] >= emocounter[7]:
    print(name, ", you are feeling surprise.")
    printstring += name+", you are feeling surprise. "
    yesorno = input("Would you like information on interpreting your feeling of surprise? Type 'yes' to proceed. ")
    if yesorno.lower() == 'yes':
      print("")
      print("Here are some ways to interpret the feeling of surprise:")
      print(" -Acknowledge and accept that surprises are unavoidable.\n -A positive outlook on a surprise can awaken ambition, motivation, and persistence.\n -To lessen the discomfort of suprises, try to incorporate small surprises into your every day life by taking a different route to work or school, trying new foods or activities, changing your routine every other day.")
    else: pass

  if emocounter[7] >= emocounter[0] and emocounter[7]>= emocounter[1] and emocounter[7] >= emocounter[2] and emocounter[7] >= emocounter[3] and emocounter[7] >= emocounter[4] and emocounter[7] >= emocounter[5] and emocounter[7] >= emocounter[6]:
    print(name, ", you are feeling trust.")
    printstring += name+", you are feeling trust. "
    yesorno = input("Would you like information on analyzing your feeling of trust? Type 'yes' to proceed. ")
    if yesorno.lower() == 'yes':
      print("")
      print("Here are some ways to interpret your feeling of trust: ")
      print(" -Trust is another way of feeling a sense of security, confidence, and dependability.\n -Think about who or what you are putting your trust in.\n -Are these people or things reliable and are they serving you in a positive way?")
    else: pass

# Adds date, user's name, user's input, and emotion they are feeling to 'ever' file
# 'a+' to append data without deleting previous additions
  with open("ever.txt", "a+") as f:
    print(x, " // ", name.title(), file=f)
    print(day, file=f)
    #print(more, file=f) 
    print(printstring, file=f)
  f.close()

# Once you run the program as many times as you want, go to the very bottom to read your entries from the ever.txt file

# %%
ever()
# Out:
# April 13, 2020
# My name is Ever. What's your name? meg
# Nice to meet you,  Meg .
#
# Tell me about your day. i rode my bike today. i don't like that it is cold outside
#
# Anger:  0 []
# Anticipation:  0 []
# Disgust:  0 []
# Fear:  0 []
# Joy:  0 []
# Sadness:  0 []
# Surprise:  0 []
# Trust:  0 []
# Meg , you are feeling angry.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
# ...

# %%
# Reading all entries from the file
with open("ever.txt") as f:
  for line in f:
    print(line)
# Out:
# April 03, 2020  //  Meg
#
# abandonment
#
# Meg, you are feeling anger. Meg, you are feeling anticipation. Meg, you are feeling disgust. Meg, you are feeling fear. Meg, you are feeling joy.Meg, you are feeling sadness. Meg, you are feeling surprise. Meg, you are feeling trust.

# %%
# This gives the user an opportunity to look up helpful tips on managing their emotions without having to write an entry
def extra():
  extra = input("Which emotion are you feeling?\n Anger\n Anticipation\n Disgust\n Fear\n Joy\n Sadness\n Surprise\n Trust\n Type one of those emotions: ")
  extra = extra.lower()
  if extra == 'anger':
    print(" -Think before you speak.\n -Get some exercise.\n -Take a timeout.\n -Identify possible solutions.\n -Stick with 'I' statements.\n -Don't hold a grudge.\n -Use humor to release tension.")
  if extra == 'anticipation':
    print(" -Focus on the positive and fun aspects of the upcoming event.\n -Remind yourself that the physical sensations you feel when anxious are harmless.\n -Practice mindfulness.")
  if extra == 'disgust':
    print(" -Notice when judmental thoughts pop into your head.\n -Remember to breathe.\n -Don't let your feelings control your thinking.\n -Do the opposite of what you're feeling.\n -Remember, it's not about you.\n -Talk to someone you trust about your feelings.")
  if extra == 'fear':
    print(" -Face your fear if you can.\n -Exercise.\n -Relax, do yoga or meditate.\n -If you're religious, find ways to connect to something bigger than yourself.")
  if extra == 'joy':
    print(" -Ride the productivity train.\n -Take a break and enjoy the feeling.\n -Write about it.\n -Share your joy with others by complimenting or helping someone or reaching out to friends.")
  if extra == 'sadness':
    print(" -Allow yourself to feel sad.\n -Spend time with friends or family.\n -Think about why you're feeling this way.\n -Cry if you feel like it.\n -Listen to music.\n -Write in a journal.")
  if extra == 'surprise':
    print(" -Acknowledge and accept that surprises are unavoidable.\n -A positive outlook on a surprise can awaken ambition, motivation, and persistence.\n -To lessen the discomfort of suprises, try to incorporate small surprises into your every day life by taking a different route to work or school, trying new foods or activities, changing your routine every other day.")
  if extra == 'trust':
    print(" -Trust is another way of feeling a sense of security, confidence, and dependability.\n -Think about who or what you are putting your trust in.\n -Are these people or things reliable and are they serving you in a positive way?")

# %%
extra()
# Out:
# Which emotion are you feeling?
#  Anger
#  Anticipation
#  Disgust
#  Fear
#  Joy
#  Sadness
#  Surprise
#  Trust
#  Type one of those emotions: trust
#  -Trust is another way of feeling a sense of security, confidence, and dependability.
#  -Think about who or what you are putting your trust in.
#  -Are these people or things reliable and are they serving you in a positive way?
